# %%
from pydantic_agent import Agent, AgentSettings
from pydantic_agent.tools.filesystem import (
    read_file,
    write_file,
    append_file,
    list_directory,
    file_info,
    delete_file,
    move_file,
    copy_file,
)

# Create an agent with default settings
# agent = Agent(model="gpt-4o")

# # Or load from configuration
settings = AgentSettings()  # Reads from env vars, .env, config.toml
agent = Agent.from_settings(settings,
tools=[
    read_file,
    write_file])

# # Run the agent
# result = await agent.run("What files are in the current directory?")
# print(result.output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 18
#      13 # Create an agent with default settings
#      14 # agent = Agent(model="gpt-4o")
#      15
#      16 # # Or load from configuration
#      17 settings = AgentSettings()  # Reads from env vars, .env, config.toml
# ---> 18 agent = Agent.from_settings(settings,
#      19 tools=[
#      20     read_file,
#      21     write_file])
#      23 # # Run the agent
#      24 # result = await agent.run("What files are in the current directory?")
#      25 # print(result.output)
#
# File ~/dev/repos/pydantic-agent/src/pydantic_agent/agent/core.py:128, in Agent.from_settings(cls, settings, tools, system_prompt, deps_type, output_type)
#     114 from pydantic_ai.providers.openai import OpenAIProvider
#     116 model = OpenAIChatModel(
#     117     settings.model_backend.model,
#     118     provider=OpenAIProvider(
#    (...)    125     ),
#     126 )
# --> 128 return cls(
#     129     model,
#     130     tools=tools,
#     131     system_prompt=system_prompt,
#     132     deps_type=deps_type,
#     133     output_type=output_type,
#     134     settings=settings,
#     135 )
#
# File ~/dev/repos/pydantic-agent/src/pydantic_agent/agent/core.py:85, in Agent.__init__(self, model, tools, system_prompt, deps_type, output_type, config, settings)
#      82 if output_type:
#      83     agent_kwargs["output_type"] = output_type
# ---> 85 self._agent: PydanticAgent[DepsT, OutputT] = PydanticAgent(model, **agent_kwargs)
#
# File ~/dev/repos/pydantic-agent/.venv/lib/python3.12/site-packages/pydantic_ai/agent/__init__.py:368, in Agent.__init__(self, model, output_type, instructions, system_prompt, deps_type, name, model_settings, retries, validation_context, output_retries, tools, builtin_tools, prepare_tools, prepare_output_tools, toolsets, defer_model_check, end_strategy, instrument, metadata, history_processors, event_stream_handler, tool_timeout, **_deprecated_kwargs)
#     365 if self._output_toolset:
#     366     self._output_toolset.max_retries = self._max_result_retries
# --> 368 self._function_toolset = _AgentFunctionToolset(
#     369     tools,
#     370     max_retries=self._max_tool_retries,
#     371     timeout=self._tool_timeout,
#     372     output_schema=self._output_schema,
#     373 )
#     374 self._dynamic_toolsets = [
#     375     DynamicToolset[AgentDepsT](toolset_func=toolset)
#     376     for toolset in toolsets or []
#     377     if not isinstance(toolset, AbstractToolset)
#     378 ]
#     379 self._user_toolsets = [toolset for toolset in toolsets or [] if isinstance(toolset, AbstractToolset)]
#
# File ~/dev/repos/pydantic-agent/.venv/lib/python3.12/site-packages/pydantic_ai/agent/__init__.py:1716, in _AgentFunctionToolset.__init__(self, tools, max_retries, timeout, id, output_schema)
#    1706 def __init__(
#    1707     self,
#    1708     tools: Sequence[Tool[AgentDepsT] | ToolFuncEither[AgentDepsT, ...]] = [],
#    (...)   1713     output_schema: _output.OutputSchema[Any],
#    1714 ):
#    1715     self.output_schema = output_schema
# -> 1716     super().__init__(tools, max_retries=max_retries, timeout=timeout, id=id)
#
# File ~/dev/repos/pydantic-agent/.venv/lib/python3.12/site-packages/pydantic_ai/toolsets/function.py:110, in FunctionToolset.__init__(self, tools, max_retries, timeout, docstring_format, require_parameter_descriptions, schema_generator, strict, sequential, requires_approval, metadata, id)
#     108     self.add_tool(tool)
#     109 else:
# --> 110     self.add_function(tool)
#
# File ~/dev/repos/pydantic-agent/.venv/lib/python3.12/site-packages/pydantic_ai/toolsets/function.py:305, in FunctionToolset.add_function(self, func, takes_ctx, name, description, retries, prepare, docstring_format, require_parameter_descriptions, schema_generator, strict, sequential, requires_approval, metadata, timeout)
#     302 if requires_approval is None:
#     303     requires_approval = self.requires_approval
# --> 305 tool = Tool[AgentDepsT](
#     306     func,
#     307     takes_ctx=takes_ctx,
#     308     name=name,
#     309     description=description,
#     310     max_retries=retries,
#     311     prepare=prepare,
#     312     docstring_format=docstring_format,
#     313     require_parameter_descriptions=require_parameter_descriptions,
#     314     schema_generator=schema_generator,
#     315     strict=strict,
#     316     sequential=sequential,
#     317     requires_approval=requires_approval,
#     318     metadata=metadata,
#     319     timeout=timeout,
#     320 )
#     321 self.add_tool(tool)
#
# File ~/.local/share/uv/python/cpython-3.12.9-macos-aarch64-none/lib/python3.12/typing.py:1184, in _BaseGenericAlias.__call__(self, *args, **kwargs)
#    1181 if not self._inst:
#    1182     raise TypeError(f"Type {self._name} cannot be instantiated; "
#    1183                     f"use {self.__origin__.__name__}() instead")
# -> 1184 result = self.__origin__(*args, **kwargs)
#    1185 try:
#    1186     result.__orig_class__ = self
#
# File ~/dev/repos/pydantic-agent/.venv/lib/python3.12/site-packages/pydantic_ai/tools.py:364, in Tool.__init__(self, function, takes_ctx, max_retries, name, description, prepare, docstring_format, require_parameter_descriptions, schema_generator, strict, sequential, requires_approval, metadata, timeout, function_schema)
#     305 """Create a new tool instance.
#     306
#     307 Example usage:
#    (...)    361     function_schema: The function schema to use for the tool. If not provided, it will be generated.
#     362 """
#     363 self.function = function
# --> 364 self.function_schema = function_schema or _function_schema.function_schema(
#     365     function,
#     366     schema_generator,
#     367     takes_ctx=takes_ctx,
#     368     docstring_format=docstring_format,
#     369     require_parameter_descriptions=require_parameter_descriptions,
#     370 )
#     371 self.takes_ctx = self.function_schema.takes_ctx
#     372 self.max_retries = max_retries
#
# File ~/dev/repos/pydantic-agent/.venv/lib/python3.12/site-packages/pydantic_ai/_function_schema.py:94, in function_schema(function, schema_generator, takes_ctx, docstring_format, require_parameter_descriptions)
#      81 """Build a Pydantic validator and JSON schema from a tool function.
#      82
#      83 Args:
#    (...)     91     A `FunctionSchema` instance.
#      92 """
#      93 if takes_ctx is None:
# ---> 94     takes_ctx = _takes_ctx(function)
#      96 config = ConfigDict(title=function.__name__, use_attribute_docstrings=True)
#      97 config_wrapper = ConfigWrapper(config)
#
# File ~/dev/repos/pydantic-agent/.venv/lib/python3.12/site-packages/pydantic_ai/_function_schema.py:263, in _takes_ctx(callable_obj)
#     260     else:
#     261         return False  # pragma: no cover
# --> 263 type_hints = _typing_extra.get_function_type_hints(_decorators.unwrap_wrapped_function(callable_obj))
#     264 annotation = type_hints.get(first_param_name)
#     265 if annotation is None:
#
# File ~/dev/repos/pydantic-agent/.venv/lib/python3.12/site-packages/pydantic/_internal/_typing_extra.py:596, in get_function_type_hints(function, include_keys, globalns, localns)
#     593     elif isinstance(value, str):
#     594         value = _make_forward_ref(value)
# --> 596     type_hints[name] = eval_type_backport(value, globalns, localns, type_params)
#     598 return type_hints
#
# File ~/dev/repos/pydantic-agent/.venv/lib/python3.12/site-packages/pydantic/_internal/_typing_extra.py:455, in eval_type_backport(value, globalns, localns, type_params)
#     445 """An enhanced version of `typing._eval_type` which will fall back to using the `eval_type_backport`
#     446 package if it's installed to let older Python versions use newer typing constructs.
#     447
#    (...)    452 This function will also display a helpful error if the value passed fails to evaluate.
#     453 """
#     454 try:
# --> 455     return _eval_type_backport(value, globalns, localns, type_params)
#     456 except TypeError as e:
#     457     if 'Unable to evaluate type annotation' in str(e):
#
# File ~/dev/repos/pydantic-agent/.venv/lib/python3.12/site-packages/pydantic/_internal/_typing_extra.py:492, in _eval_type_backport(value, globalns, localns, type_params)
#     485 def _eval_type_backport(
#     486     value: Any,
#     487     globalns: GlobalsNamespace | None = None,
#     488     localns: MappingNamespace | None = None,
#     489     type_params: tuple[Any, ...] | None = None,
#     490 ) -> Any:
#     491     try:
# --> 492         return _eval_type(value, globalns, localns, type_params)
#     493     except TypeError as e:
#     494         if not (isinstance(value, typing.ForwardRef) and is_backport_fixable_error(e)):
#
# File ~/dev/repos/pydantic-agent/.venv/lib/python3.12/site-packages/pydantic/_internal/_typing_extra.py:545, in _eval_type(value, globalns, localns, type_params)
#     541     return typing._eval_type(  # type: ignore
#     542         value, globalns, localns, type_params=type_params
#     543     )
#     544 else:
# --> 545     return typing._eval_type(  # type: ignore
#     546         value, globalns, localns
#     547     )
#
# File ~/.local/share/uv/python/cpython-3.12.9-macos-aarch64-none/lib/python3.12/typing.py:415, in _eval_type(t, globalns, localns, type_params, recursive_guard)
#     408 """Evaluate all forward references in the given type t.
#     409
#     410 For use of globalns and localns see the docstring for get_type_hints().
#     411 recursive_guard is used to prevent infinite recursion with a recursive
#     412 ForwardRef.
#     413 """
#     414 if isinstance(t, ForwardRef):
# --> 415     return t._evaluate(globalns, localns, type_params, recursive_guard=recursive_guard)
#     416 if isinstance(t, (_GenericAlias, GenericAlias, types.UnionType)):
#     417     if isinstance(t, GenericAlias):
#
# File ~/.local/share/uv/python/cpython-3.12.9-macos-aarch64-none/lib/python3.12/typing.py:952, in ForwardRef._evaluate(self, globalns, localns, type_params, recursive_guard)
#     944                 localns.pop(param_name, None)
#     946     type_ = _type_check(
#     947         eval(self.__forward_code__, globalns, localns),
#     948         "Forward references must evaluate to types.",
#     949         is_argument=self.__forward_is_argument__,
#     950         allow_special_forms=self.__forward_is_class__,
#     951     )
# --> 952     self.__forward_value__ = _eval_type(
#     953         type_,
#     954         globalns,
#     955         localns,
#     956         type_params,
#     957         recursive_guard=(recursive_guard | {self.__forward_arg__}),
#     958     )
#     959     self.__forward_evaluated__ = True
#     960 return self.__forward_value__
#
# File ~/.local/share/uv/python/cpython-3.12.9-macos-aarch64-none/lib/python3.12/typing.py:415, in _eval_type(t, globalns, localns, type_params, recursive_guard)
#     408 """Evaluate all forward references in the given type t.
#     409
#     410 For use of globalns and localns see the docstring for get_type_hints().
#     411 recursive_guard is used to prevent infinite recursion with a recursive
#     412 ForwardRef.
#     413 """
#     414 if isinstance(t, ForwardRef):
# --> 415     return t._evaluate(globalns, localns, type_params, recursive_guard=recursive_guard)
#     416 if isinstance(t, (_GenericAlias, GenericAlias, types.UnionType)):
#     417     if isinstance(t, GenericAlias):
#
# File ~/.local/share/uv/python/cpython-3.12.9-macos-aarch64-none/lib/python3.12/typing.py:947, in ForwardRef._evaluate(self, globalns, localns, type_params, recursive_guard)
#     943             globalns[param_name] = param
#     944             localns.pop(param_name, None)
#     946 type_ = _type_check(
# --> 947     eval(self.__forward_code__, globalns, localns),
#     948     "Forward references must evaluate to types.",
#     949     is_argument=self.__forward_is_argument__,
#     950     allow_special_forms=self.__forward_is_class__,
#     951 )
#     952 self.__forward_value__ = _eval_type(
#     953     type_,
#     954     globalns,
#    (...)    957     recursive_guard=(recursive_guard | {self.__forward_arg__}),
#     958 )
#     959 self.__forward_evaluated__ = True
#
# File <string>:1
#
# NameError: name 'FilesystemSecurity' is not defined

# %%
agent
